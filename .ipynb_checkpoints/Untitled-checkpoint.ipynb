# %%
import subprocess
import graph_tool.all as gt
import numpy as np
import tqdm
import random as rnd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter
import pickle
# Out:
# 32

# %%
mismatch = '1'
regex = 'G[ACGT]S'


process = subprocess.Popen(['tre-agrep', '-E', mismatch, '-e={}'.format(regex), filename],
                           stdout=subprocess.PIPE, universal_newlines=True)
stdout,stderr = process.communicate()
matches = sum(map(int,[x.split('\t')[0] for x in stdout.split('\n')[:-1]]))
matches
# Out:
# 32

# %%
spexs_df = pd.read_csv('data/specs_out.txt',sep='\t')

patterns_df = spexs_df.loc[np.array(list(map(len,spexs_df['Pat?()'])))  == 6].sort('Pat?()')

df = pd.read_csv('data/protobios_generated_data/peptides_s50_r50_m0.txt',sep='\t', header=None)[1]
#df = pd.read_csv('data/protobios_generated_data/peptides_s50_r0_m0.txt',sep='\t', header=None)[1]

PEPTIDE_LENGTH = 4
peptides = list()
for protein in df:
    for i in range(12 - PEPTIDE_LENGTH + 1):
        peptides.append(protein[i:i+PEPTIDE_LENGTH])

print(len(peptides))
# Out:
# 230562
# /usr/local/lib/python3.4/dist-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %%
testLength = len(peptides)
#testLength = 200

# %%
g = gt.Graph()

e_weight = g.new_edge_property("int")
g.edge_properties['weights'] = e_weight
e_colored = g.new_edge_property("int")
g.edge_properties['colors'] = e_colored
v_letter = g.new_vertex_property('string')
g.vertex_properties['letters'] = v_letter

root = g.add_vertex(1)
for i in tqdm.tqdm(range(testLength)):
    peptide = peptides[i]
    current = root
    for letter in peptide:
        arr = np.array([v_letter[x] == letter for x in current.out_neighbours()])
        if any(arr):
            target_index = arr.argmax()
            target = list(current.out_neighbours())[target_index]
        else:
            target = g.add_vertex()
            edge = g.add_edge(current,target)
            e_weight[edge] = 0
            e_colored[edge] = 0
            v_letter[target] = letter
        edge = g.edge(current,target)
        e_weight[edge] += 1
        current = target
# Out:
# 100%|██████████| 230562/230562 [04:32<00:00, 847.19it/s]

# %%
pickle.dump(g, open('full_graph.p', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d4a2f90e9f95> in <module>()
# ----> 1 pickle.dump(g, open('full_graph.p', 'wb'))
#
# NameError: name 'g' is not defined

# %%
g = pickle.load(open('full_graph.p', 'rb'))
root = [x for x in list(g.vertices()) if x.in_degree() == 0][0]
e_weight = g.edge_properties['weights']
e_colored = g.edge_properties['colors']
v_letter = g.vertex_properties['letters']

# %%
pos = gt.fruchterman_reingold_layout(g,weight=e_weight)
gt.graph_draw(g, pos=pos,edge_color=e_colored)

# %%
patterns = patterns_df['Pat?()']

#print(len(patterns))

def ifBetterThanRandom(amountOfPatterns,weight, depth):
    threshold = amountOfPatterns*(1/20)**depth
    #print(depth)
    print(weight,threshold)
    if weight > threshold:
        return True
    else:
        return False

for pattern in patterns:
    vertices = set()
    nextVertices = set()
    nextVertices.add(root)
    depth = 0
    for letter in pattern:
        vertices = nextVertices.copy()
        nextVertices = set()
        depth += 1
        for current in vertices:
            if letter == '.':
                #print('Found points')
                for neighbor in list(current.out_neighbours()):
                    edge = g.edge(current,neighbor)
                    weight = e_weight[edge]
                    #print(weight)
                    if ifBetterThanRandom(testLength, weight, depth):
                        e_colored[edge] = 1
                        nextVertices.add(neighbor)
                    else:
                        print("NOT")
            else:
                try:
                    neighbor = [x for x in current.out_neighbours() if v_letter[x] == letter][0]
                except IndexError:
                    continue
                #print("NEW")
                #print(letter)
                #print(v_letter[neighbor])
                edge = g.edge(current,neighbor)
                weight = e_weight[edge]
                if ifBetterThanRandom(testLength, weight, depth):
                    e_colored[edge] = 1
                    nextVertices.add(neighbor)
                else:
                    print("NOT2")
# Out:
# 10314 11528.1
# NOT2
# 10314 11528.1
# NOT2
# 10314 11528.1
# NOT2
# 10314 11528.1
# NOT2
# 10314 11528.1
# NOT2
# 10314 11528.1
# NOT2
# 10314 11528.1
# NOT2
# 10314 11528.1
# NOT2
# 12126 11528.1
# 568 576.4050000000001
# NOT
# 727 576.4050000000001
# 669 576.4050000000001
# 538 576.4050000000001
# NOT
# 529 576.4050000000001
# NOT
# 545 576.4050000000001
# NOT
# 545 576.4050000000001
# NOT
# 522 576.4050000000001
# NOT
# 548 576.4050000000001
# NOT
# 797 576.4050000000001
# 630 576.4050000000001
# 522 576.4050000000001
# NOT
# 588 576.4050000000001
# 602 576.4050000000001
# 699 576.4050000000001
# 741 576.4050000000001
# 651 576.4050000000001
# 608 576.4050000000001
# 496 576.4050000000001
# NOT
# 601 576.4050000000001
# 58 28.82025000000001
# 67 28.82025000000001
# 57 28.82025000000001
# 38 28.82025000000001
# 38 28.82025000000001
# 31 28.82025000000001
# 37 28.82025000000001
# 25 28.82025000000001
# NOT
# 22 28.82025000000001
# NOT
# 41 28.82025000000001
# 19 28.82025000000001
# NOT
# 34 28.82025000000001
# 28 28.82025000000001
# NOT
# 29 28.82025000000001
# 31 28.82025000000001
# 24 28.82025000000001
# NOT
# 66 28.82025000000001
# 22 28.82025000000001
# NOT
# 24 28.82025000000001
# NOT
# 36 28.82025000000001
# 42 28.82025000000001
# 19 28.82025000000001
# NOT
# 30 28.82025000000001
# 24 28.82025000000001
# NOT
# 135 28.82025000000001
# 32 28.82025000000001
# 54 28.82025000000001
# 20 28.82025000000001
# NOT
# 39 28.82025000000001
# 22 28.82025000000001
# NOT
# 25 28.82025000000001
# NOT
# 26 28.82025000000001
# NOT
# 35 28.82025000000001
# 27 28.82025000000001
# NOT
# 22 28.82025000000001
# NOT
# 28 28.82025000000001
# NOT
# 21 28.82025000000001
# NOT
# 12 28.82025000000001
# NOT
# 19 28.82025000000001
# NOT
# 19 28.82025000000001
# NOT
# 28 28.82025000000001
# NOT
# 39 28.82025000000001
# 24 28.82025000000001
# NOT
# 38 28.82025000000001
# 25 28.82025000000001
# NOT
# 38 28.82025000000001
# 27 28.82025000000001
# NOT
# 23 28.82025000000001
# NOT
# 23 28.82025000000001
# NOT
# 22 28.82025000000001
# NOT
# 26 28.82025000000001
# NOT
# 44 28.82025000000001
# 28 28.82025000000001
# NOT
# 33 28.82025000000001
# 25 28.82025000000001
# NOT
# 25 28.82025000000001
# NOT
# 35 28.82025000000001
# 37 28.82025000000001
# 35 28.82025000000001
# 33 28.82025000000001
# 26 28.82025000000001
# NOT
# 33 28.82025000000001
# 33 28.82025000000001
# 40 28.82025000000001
# 45 28.82025000000001
# 49 28.82025000000001
# 33 28.82025000000001
# 48 28.82025000000001
# 29 28.82025000000001
# 33 28.82025000000001
# 31 28.82025000000001
# 28 28.82025000000001
# NOT
# 32 28.82025000000001
# 39 28.82025000000001
# 36 28.82025000000001
# 20 28.82025000000001
# NOT
# 33 28.82025000000001
# 22 28.82025000000001
# NOT
# 31 28.82025000000001
# 28 28.82025000000001
# NOT
# 56 28.82025000000001
# 43 28.82025000000001
# 42 28.82025000000001
# 33 28.82025000000001
# 27 28.82025000000001
# NOT
# 26 28.82025000000001
# NOT
# 26 28.82025000000001
# NOT
# 23 28.82025000000001
# NOT
# 19 28.82025000000001
# NOT
#
# 14 1.4410125000000003
# 17 1.4410125000000003
# 18 1.4410125000000003
# 18 1.4410125000000003
# 11 1.4410125000000003
# 16 1.4410125000000003
# 14 1.4410125000000003
# 25 1.4410125000000003
# 18 1.4410125000000003
# 19 1.4410125000000003
# 15 1.4410125000000003
# 11935 11528.1
# 910 576.4050000000001
# 388 28.82025000000001
# 27 1.4410125000000003
# 23 1.4410125000000003
# 27 1.4410125000000003
# 16 1.4410125000000003
# 21 1.4410125000000003
# 22 1.4410125000000003
# 17 1.4410125000000003
# 26 1.4410125000000003
# 24 1.4410125000000003
# 14 1.4410125000000003
# 17 1.4410125000000003
# 18 1.4410125000000003
# 18 1.4410125000000003
# 11 1.4410125000000003
# 16 1.4410125000000003
# 14 1.4410125000000003
# 25 1.4410125000000003
# 18 1.4410125000000003
# 19 1.4410125000000003
# 15 1.4410125000000003

# %%
#
# Global variables
# Setup optimal string and GA input variables.
#

OPTIMAL     = "Hello, World"
IND_SIZE    = len(OPTIMAL)
POP_SIZE    = 20
GENERATIONS = 5000
ALPHABET = 'GPAVLIMCFYWHKRQNEDST'
filename='data/protobios_generated_data/peptides_s50_r0_m0.txt'



def grep(filename, mismatch,regex):
    process = subprocess.Popen(['tre-agrep', '-E', mismatch, '-e={}'.format(regex), filename],
                               stdout=subprocess.PIPE, universal_newlines=True)
    stdout,stderr = process.communicate()
    matches = sum(map(int,[x.split('\t')[0] for x in stdout.split('\n')[:-1]]))
    
    return matches


def possible_strings(individual):
    n = 0
    for group in individual:
        if len(group) == 1:
            if group == '.':
                n *= 20
            else:
                n += 1
        else:
            n *= len(group)
    return n
            

# GA functions
# These make up the bulk of the actual GA algorithm.

def get_fitness(individual):
    individual = ['[{}]'.format(x) if len(x)>1 else x for x in individual]
    matches = grep(filename,'0',''.join(individual))
    specificity = possible_strings(individual)
    
    return matches - specificity*5

def remove_letter(group):
    """
    Helper function for mutation.
    Removes one letter from a group.
    If letter is the last one in group,
    returns empty string
    """
    if group == '.':
        group = np.random.choice(ALPHABET,19)
    elif len(group) == 1:
        return ''
    else:
        group = np.random.choice(group,len(group)-1)
    return group

def add_letter_rec(individual,i,j,vertex):
    """
    Helper function for add_letter.
    Finds all compatible nodes for an individual
    on requested level
    """
    if i == j:
        return [x.target() for x in vertex.out_edges() if e_colored[x] == 1]
    result=[]
    for v in [x.target() for x in vertex.out_edges() if e_colored[x] == 1]:
        result.extend(add_letter_rec(individual, i, j+1, v))
    return result


def add_letter(individual,depth):
    """
    Helper function for mutate.
    Gets all compatible nodes on the required level
    and returns a letter chosen with weighed random
    function where weight is the probability of
    the letter considering the preceeding regex
    """
    candidates = add_letter_rec(individual,depth,0,root)
    lcounts = {}
    for c in candidates:
        if v_letter[c] in lcounts:
            lcounts[v_letter[c]] += e_weight[list(c.in_edges())[0]]
        else:
            lcounts[v_letter[c]] = e_weight[list(c.in_edges())[0]]
    letters = []
    weigths = np.array([])
    for k,v in lcounts.items():
        letters.append(k)
        np.append(weigths,v)
    return np.random.choice(letters,1,weigths/weigths.sum())[0]

         
    
    
def mutate(individual):
    """
    Function that performs mutation on individuals
    with the given mutation_chance probability
    Chooses randomly from three different mechanisms
    """
    m_individual = []
    mutation_chance = 0.01
    for i in range(len(individual)):
        c = individual[i]
        if np.random.randint(0,100)/100 < mutation_chance:
            mut_choice = np.random.random()
            if mut_choice<0.33:
                c = remove_letter(c)
            if 0.33<mut_choice<0.66:
                c = add_letter(individual,i)
            else:
                c = switch_letter(c)
                
                    
        m_individual.append(c)
    return m_individual

def crossover(individual1,individual2):
    """
    Crossover function.
    Switches random groups
    between two individuals
    """
    idx = np.random.choice(range(len(individual1)),0.5*len(individual1),replace=False)
    old_individual1 = individual1.copy()
    individual1[idx] = individual2[idx]
    individual2[idx] = individual1[idx]
    return individual1,individual2

candidates = pd.read_csv('data/specs_out.txt',sep='\t')['Pat?()'].values

# %%
class individual(object):
    
    def __init__(self,value,fitfunc):
        self.feature = value
        self.fitness_func = fitfunc
        self.fitness = 0
        
    def __lt__(self, other):
         return self.fitness < other.fitness
        
    def __repr__(self):
        return self.feature
    
    def get_fitness(self):
        self.fitness = self.fitness_func(self.feature)
       
        
ind = individual(candidates[0],get_fitness)
individuals = [individual(x,get_fitness) for x in candidates[:10]]


#for _ in range(GENERATIONS):
for individual in individuals:
    individual.get_fitness()    

individuals = sorted(individuals)
for c1, c2 in zip(individuals[::2],individuals[1::2]):
    c1,c2 = crossover(c1, c2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-fdc3235261b3> in <module>()
#      25 individuals = sorted(individuals)
#      26 for c1, c2 in zip(individuals[::2],individuals[1::2]):
# ---> 27     c1,c2 = crossover(c1, c2)
#      28
#      29
#
# <ipython-input-65-eaa5dd1a0c53> in crossover(individual1, individual2)
#     128     between two individuals
#     129     """
# --> 130     idx = np.random.choice(range(len(individual1)),0.5*len(individual1),replace=False)
#     131     old_individual1 = individual1.copy()
#     132     individual1[idx] = individual2[idx]
#
# TypeError: object of type 'individual' has no len()

# %%
individual
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /usr/local/lib/python3.4/dist-packages/IPython/lib/pretty.py in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /usr/local/lib/python3.4/dist-packages/IPython/lib/pretty.py in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# /usr/local/lib/python3.4/dist-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     692     """A pprint that just redirects to the normal repr function."""
#     693     # Find newlines and replace them with p.break_()
# --> 694     output = repr(obj)
#     695     for idx,output_line in enumerate(output.splitlines()):
#     696         if idx:
#
# TypeError: __repr__ returned non-string (type list)
